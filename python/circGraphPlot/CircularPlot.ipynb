# %%
# %matplotlib inline
import mne

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from mne.viz import circular_layout, plot_connectivity_circle

# %%
numNodes = 66;
test = np.random.rand(numNodes,numNodes)
test[test<0.95] = 0
names = []
for j in range(0,numNodes):
    names.append(unicode(str(j)))

# %%
plot_connectivity_circle(test,names,vmin=0.95,vmax=1)
# Out:
# (<matplotlib.figure.Figure at 0x141de9d0>,
#  <matplotlib.axes._subplots.PolarAxesSubplot at 0x141dc4d0>)

# %%
# %debug
# Out:
# > /net/store/nbp/projects/phasesim/python/env/local/lib/python2.7/site-packages/mne/viz/circle.py(253)plot_connectivity_circle()
#     252         if con.shape[0] != n_nodes or con.shape[1] != n_nodes:
# --> 253             raise ValueError('con has to be 1D or a square matrix')
#     254         # we use the lower-triangular part
#
# ipdb> exit
